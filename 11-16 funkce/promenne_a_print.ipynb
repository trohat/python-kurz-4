# %%
cislo = 5

# %%
cislo = cislo + 3

# %%
cislo
# Out:
# 8

# %%
cislo += 3

# %%
cislo
# Out:
# 11

# %%
cislo *= 2

# %%
cislo
# Out:
# 22

# %%
def privitani(jmeno, napoj):
    print(f"Ahoj {jmeno}, vítám tě na oslavě narozenin")
    print("Je tu zima, doufám, že máš teplé ponožky")
    if napoj == "pivo":
        print("Pivo je schované pod schodama, můžeš si tam jedno vzít")
    else:
        print(f"Svůj oblíbený {napoj} si musíš najít.")

# %%
privitani
# Out:
# <function __main__.privitani(jmeno, napoj)>

# %%
print
# Out:
# <function print>

# %%
print()

# %%
print("ahoj")
# Out:
# ahoj

# %%
print("ahoj", "Jirko", "jak se máš")
# Out:
# ahoj Jirko jak se máš

# %%
print("ahoj", "Jirko", "jak se máš", sep="*")
# Out:
# ahoj*Jirko*jak se máš

# %%
print("ahoj", "Jirko", "jak se máš", sep="*----*")
# Out:
# ahoj*----*Jirko*----*jak se máš

# %%
print("ahoj", "Jirko", "jak se máš", sep="**princezna**", end="--kašpárek v rohlíku--")
print("Mám se dobře")
# Out:
# ahoj**princezna**Jirko**princezna**jak se máš--kašpárek v rohlíku--Mám se dobře

# %%
print("ahoj", "Petře")
# Out:
# ahoj

# %%
print("ahoj", "Petře", sep=" ", end="\n")

# %%
print(f"Funkce print vrací {print('ahoj')}")
# Out:
# ahoj
# Funkce print vrací None
