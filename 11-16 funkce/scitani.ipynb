# %%
def scitani(cislo1, cislo2):
    vysledek = cislo1 + cislo2
    print(f"Výsledek je {vysledek}")

# %%
scitani(5, 6)
# Out:
# Výsledek je 11

# %%
soucet = scitani(5, 6)
# Out:
# Výsledek je 11

# %%
print(soucet)
# Out:
# None

# %%
def scitani(cislo1, cislo2):
    vysledek = cislo1 + cislo2
    return f"Výsledek je {vysledek}"

# %%
soucet = scitani(5, 6)
print("Konec")
print(soucet)
# Out:
# Konec
# Výsledek je 11

# %%
def scitani(cislo1, cislo2):
    vysledek = cislo1 + cislo2
    return vysledek

# %%
soucet1 = scitani(23, 12)
soucet2 = scitani(5, 6)
soucet3 = scitani(soucet1, soucet2)

print(soucet3)
# Out:
# 46
