# %%
anglictina = {
    "dřevo": "wood",
    "les": "forest",
    "ovce": "sheep",
    "jablko": "apple",
    "pes": "dog"
}

# %%
anglictina
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Trohat\Desktop\Python kurz 4\11-30 slovniky\slovniky.ipynb Cell 3 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Trohat/Desktop/Python%20kurz%204/11-30%20slovniky/slovniky.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> anglictina
#
# NameError: name 'anglictina' is not defined

# %%
anglictina["dřevo"]
# Out:
# 'wood'

# %%
anglictina["pes"]
# Out:
# 'dog'

# %%
anglictina["kočka"] = "cat"
anglictina
# Out:
# {'dřevo': 'wood',
#  'les': 'forest',
#  'ovce': 'sheep',
#  'jablko': 'apple',
#  'pes': 'dog',
#  'kočka': 'cat'}

# %%
anglictina
# Out:
# {'dřevo': 'wood',
#  'les': 'forest',
#  'ovce': 'sheep',
#  'jablko': 'apple',
#  'pes': 'dog',
#  'kočka': 'cat'}

# %%
anglictina["dřevo"] = "iron"
anglictina
# Out:
# {'dřevo': 'iron',
#  'les': 'forest',
#  'ovce': 'sheep',
#  'jablko': 'apple',
#  'pes': 'dog',
#  'kočka': 'cat'}

# %%
len(anglictina)
# Out:
# 6

# %%
"les" in anglictina
# Out:
# True

# %%
"myš" in anglictina
# Out:
# False

# %%
"apple" in anglictina
# Out:
# False

# %%
anglictina["les"]
# Out:
# 'forest'

# %%
anglictina["chameleon"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-0f37d39b0280> in <cell line: 1>()
# ----> 1 anglictina["chameleon"]
#
# KeyError: 'chameleon'

# %%
del anglictina["pes"]
anglictina
# Out:
# {'dřevo': 'iron',
#  'les': 'forest',
#  'ovce': 'sheep',
#  'jablko': 'apple',
#  'kočka': 'cat'}

# %%
clovek = {
    "jmeno": "Petr",
    "prijmeni": "Sedláček",
    "vek": 15,
    "oblibena barva": "oranžová",
    "je muž": True,
    "je žena": False,
    "oblíbené jazyky": ["JavaScript", "Python", "SmallTalk"],
    "partner": {
        "jmeno": "Katka",
        "prijmeni": "Nováková",
        "vek": 16,
        "oblíbená barva": "žlutá",
        "oblíbené jazyky": ["Java", "Python"],
    },
    "oblíbená soutěž": "Advent of Code"
}

# %%
clovek["oblíbené jazyky"][2]
# Out:
# 'SmallTalk'

# %%
type(clovek)
# Out:
# dict

# %%
type(clovek["oblíbené jazyky"])
# Out:
# list

# %%
print(clovek)
# Out:
# {'jmeno': 'Petr', 'prijmeni': 'Sedláček', 'vek': 15, 'oblibena barva': 'oranžová', 'je muž': True, 'je žena': False, 'oblíbené jazyky': ['JavaScript', 'Python', 'SmallTalk'], 'partner': {'jmeno': 'Katka', 'prijmeni': 'Nováková', 'vek': 16, 'oblíbená barva': 'žlutá', 'oblíbené jazyky': ['Java', 'Python']}, 'oblíbená soutěž': 'Advent of Code'}

# %%
for klic in clovek.keys():
    print(klic)
# Out:
# jmeno
# prijmeni
# vek
# oblibena barva
# je muž
# je žena
# oblíbené jazyky
# partner
# oblíbená soutěž

# %%
for hodnota in clovek.values():
    print(hodnota)
# Out:
# Petr
# Sedláček
# 15
# oranžová
# True
# False
# ['JavaScript', 'Python', 'SmallTalk']
# {'jmeno': 'Katka', 'prijmeni': 'Nováková', 'vek': 16, 'oblíbená barva': 'žlutá', 'oblíbené jazyky': ['Java', 'Python']}
# Advent of Code

# %%
for oboji in clovek.items():
    print(f"Klíč je {oboji[0]}, hodnota je {oboji[1]}")
# Out:
# Klíč je jmeno, hodnota je Petr
# Klíč je prijmeni, hodnota je Sedláček
# Klíč je vek, hodnota je 15
# Klíč je oblibena barva, hodnota je oranžová
# Klíč je je muž, hodnota je True
# Klíč je je žena, hodnota je False
# Klíč je oblíbené jazyky, hodnota je ['JavaScript', 'Python', 'SmallTalk']
# Klíč je partner, hodnota je {'jmeno': 'Katka', 'prijmeni': 'Nováková', 'vek': 16, 'oblíbená barva': 'žlutá', 'oblíbené jazyky': ['Java', 'Python']}
# Klíč je oblíbená soutěž, hodnota je Advent of Code
