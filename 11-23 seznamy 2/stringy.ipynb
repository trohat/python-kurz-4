# %%
pozdrav = "chameleon"
seznam = ["míč", "pes", "lavička", "strom", "trávník"]
print("Pavel řekl: \"Ahoj\".")
print('Pavel řekl: "Ahoj".')
# Out:
# Pavel řekl: "Ahoj".
# Pavel řekl: "Ahoj".

# %%
seznam[3]
# Out:
# 'strom'

# %%
pozdrav[3]
# Out:
# 'm'

# %%
pozdrav[5]
# Out:
# 'l'

# %%
pozdrav
# Out:
# 'chameleon'

# %%
pozdrav[2:6]
# Out:
# 'amel'

# %%
pozdrav[:6]
# Out:
# 'chamel'

# %%
max(pozdrav)
# Out:
# 'o'

# %%
min(pozdrav)
# Out:
# 'a'

# %%
len(pozdrav)
# Out:
# 9

# %%
pozdrav[2:]
# Out:
# 'ameleon'

# %%
pozdrav[:]
# Out:
# 'chameleon'

# %%
pozdrav[2:7:2]
# Out:
# 'aee'

# %%
pozdrav[::-1]
# Out:
# 'noelemahc'

# %%
seznam.sort()
seznam
# Out:
# ['lavička', 'míč', 'pes', 'strom', 'trávník']

# %%
seznam
# Out:
# ['lavička', 'míč', 'pes', 'strom', 'trávník']

# %%
seznam[3][2]
# Out:
# 'r'

# %%
for pismeno in pozdrav:
    print(f"Další písmeno je {pismeno}")
# Out:
# Další písmeno je c
# Další písmeno je h
# Další písmeno je a
# Další písmeno je m
# Další písmeno je e
# Další písmeno je l
# Další písmeno je e
# Další písmeno je o
# Další písmeno je n

# %%
"velký slon"[3]
# Out:
# 'k'

# %%
pozdrav.upper()
# Out:
# 'CHAMELEON'

# %%
"opice".upper()
# Out:
# 'OPICE'

# %%
pozdrav = pozdrav.upper()
pozdrav
# Out:
# 'CHAMELEON'

# %%
for slovo in seznam:
    print(slovo.upper())
# Out:
# LAVIČKA
# MÍČ
# PES
# STROM
# TRÁVNÍK

# %%
slovo = seznam
type(slovo)
slovo
# Out:
# ['lavička', 'míč', 'pes', 'strom', 'trávník']

# %%
seznam[3:5].upper()
# Out:
# 'STROM'

# %%
pozdrav.lower()
# Out:
# 'chameleon'

# %%
"ahoj Karle jak se máš".title()
# Out:
# 'Ahoj Karle Jak Se Máš'

# %%
"ahoj Karle jak se máš".capitalize()
# Out:
# 'Ahoj karle jak se máš'

# %%
"SLON".isupper()
# Out:
# True

# %%
"slon".isupper()
# Out:
# False

# %%
"sLon".islower()
# Out:
# False

# %%
"slon".isdigit()
# Out:
# False

# %%
"12345".isdigit()
# Out:
# True

# %%
"abc123".isalnum()
# Out:
# True

# %%
"šššš@".isalnum()
# Out:
# False

# %%
"já jsem velká opice".find("opice")
# Out:
# 14

# %%
"já jsem velká opice".find("slon")
# Out:
# -1

# %%
"já jsem velká opice".index("slon")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-520e506cc5aa> in <cell line: 1>()
# ----> 1 "já jsem velká opice".index("slon")
#
# ValueError: substring not found

# %%
"já jsem velká opice".index("opice")
# Out:
# 14

# %%
"šla jedna opice a druhá opice a třetí opice".count("opice")
# Out:
# 3

# %%
"šla jedna opice a druhá opice a třetí opice".replace("opice", "veverka")
# Out:
# 'šla jedna veverka a druhá veverka a třetí veverka'

# %%
"šla jedna opice a druhá opice a třetí opice".split()
# Out:
# ['šla', 'jedna', 'opice', 'a', 'druhá', 'opice', 'a', 'třetí', 'opice']

# %%
veta = "šla jedna opice a druhá opice a třetí opice"
roztrhana_veta = veta.split()
roztrhana_veta.sort()
print(type(roztrhana_veta))
print(roztrhana_veta)
veta = " ".join(roztrhana_veta)
veta
# Out:
# <class 'list'>
# ['a', 'a', 'druhá', 'jedna', 'opice', 'opice', 'opice', 'třetí', 'šla']
# 'a a druhá jedna opice opice opice třetí šla'

# %%
"***".join(seznam)
# Out:
# 'lavička***míč***pes***strom***trávník'
