# %%
cislo1 = 5
cislo2 = cislo1
cislo1 = 7
print(cislo1, cislo2)
# Out:
# 7 5

# %%
seznam_jedna = ["Audi", "Mercedes", "Škodovka"]
jiny_seznam = seznam_jedna # tady ukazujeme na stejné místo v paměti,
                           # nedojde ke kopii
seznam_tri = seznam_jedna.copy() # kopírovat buď takto, nebo viz další řádek
seznam_ctyri = seznam_jedna[:] # tohle je nejlepší způsob kopírování seznamů,
                               # skutečně vytvoří kopii
seznam_ctyri[0] = "tříkolka"
seznam_jedna.append("BMW")
print(f"{seznam_jedna=}")
print(f"{jiny_seznam=}")
print(f"{seznam_tri=}")
print(f"{seznam_ctyri=}")
# Out:
# seznam_jedna=['Audi', 'Mercedes', 'Škodovka', 'BMW']
# jiny_seznam=['Audi', 'Mercedes', 'Škodovka', 'BMW']
# seznam_tri=['Audi', 'Mercedes', 'Škodovka']
# seznam_ctyri=['tříkolka', 'Mercedes', 'Škodovka']
