# %%
for i in range(2, 6):
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
zacatek = 2
konec = 6
for i in range(zacatek, konec):
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
konec = 106 - 100
for i in range(10 - 8, konec):
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
for i in range(18 / 9, 1 + 2 + 3):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7e00ea6e9931> in <cell line: 1>()
# ----> 1 for i in range(18 / 9, 1 + 2 + 3):
#       2     print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
for i in range(18 // 9, 1 + 2 + 3):
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
for zvire in ["slon", "opice", "gorila", "velbloud"]:
    print(zvire)
# Out:
# slon
# opice
# gorila
# velbloud

# %%
seznam = ["slonFF", "opiceGG", "gorilaAA", "velbloudPP"]

vypocet = 2 + 3
for zvire in seznam:
    print(zvire)
# Out:
# slonFF
# opiceGG
# gorilaAA
# velbloudPP
