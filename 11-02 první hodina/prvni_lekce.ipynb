# %%
5 + 13
# Out:
# 18

# %%
89 * 3
# Out:
# 267

# %%
98 - 5
# Out:
# 93

# %%
98 / 5
# Out:
# 19.6

# %%
print("Ahoj světe")
print("Jak se máš")
print("Já se mám dobře...")
# Out:
# Ahoj světe
# Jak se máš
# Já se mám dobře...

# %%
print(6 + 5)
print(8 + 9)
print(11 - 3)
# Out:
# 11
# 17
# 8
