# %%
ceny = [52, 55, 62, 67, 63, 59, 45, 43]
dny = ["pondělí", "úterý", "středa", "čtvrtek", "pátek", "sobota"]
divnej_seznam = [52, "úterý", True, None, 10.5, 59, "neděle"] # není důvod dělat

# %%
dny
# Out:
# ['pondělí', 'úterý', 'středa', 'čtvrtek', 'pátek', 'sobota']

# %%
dny[2]
# Out:
# 'středa'

# %%
dny[5]
# Out:
# 'sobota'

# %%
dny[5] = "víkend"

# %%
dny
# Out:
# ['pondělí', 'úterý', 'středa', 'čtvrtek', 'pátek', 'víkend']

# %%
dny[5] = "sobota"
dny
# Out:
# ['pondělí', 'úterý', 'středa', 'čtvrtek', 'pátek', 'sobota']

# %%
dny.append("neděle")
dny
# Out:
# ['pondělí', 'úterý', 'středa', 'čtvrtek', 'pátek', 'sobota', 'neděle']

# %%
dny.reverse()
dny
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-65cc3e9e6cf3> in <cell line: 1>()
# ----> 1 dny.reverse(3)
#       2 dny
#
# TypeError: list.reverse() takes no arguments (1 given)

# %%
dny.index("čtvrtek")
# Out:
# 3

# %%
dny.sort()
dny
# Out:
# ['neděle', 'pondělí', 'pátek', 'sobota', 'středa', 'úterý', 'čtvrtek']

# %%
dny
# Out:
# ['pondělí', 'úterý', 'středa', 'čtvrtek', 'pátek', 'sobota', 'neděle']

# %%
dny.insert(2, "výuka")
dny
# Out:
# ['pondělí', 'úterý', 'výuka', 'středa', 'čtvrtek', 'pátek', 'sobota', 'neděle']

# %%
dny.remove("středa")
dny
# Out:
# ['pondělí', 'úterý', 'výuka', 'čtvrtek', 'pátek', 'sobota', 'neděle']

# %%
del dny[5]
dny
# Out:
# ['pondělí', 'úterý', 'výuka', 'čtvrtek', 'pátek', 'neděle']

# %%
dny.pop()
dny
# Out:
# ['pondělí', 'úterý', 'výuka', 'čtvrtek', 'pátek']

# %%
dny.pop(2)
dny
# Out:
# ['pondělí', 'úterý', 'čtvrtek', 'pátek']

# %%
dny[5]
dny
# Out:
# ['pondělí', 'úterý', 'středa', 'čtvrtek', 'pátek', 'sobota', 'neděle']

# %%
dny[-2]
# Out:
# 'sobota'

# %%
dny[-1]
# Out:
# 'neděle'

# %%
dny[2:5]
# Out:
# ['středa', 'čtvrtek', 'pátek']

# %%
dny[:5]
# Out:
# ['pondělí', 'úterý', 'středa', 'čtvrtek', 'pátek']

# %%
dny[2:]
# Out:
# ['středa', 'čtvrtek', 'pátek', 'sobota', 'neděle']

# %%
dny[1:3]
# Out:
# ['úterý', 'středa']

# %%
dny[1:5:2]
# Out:
# ['úterý', 'čtvrtek']

# %%
dny[::-1]
# Out:
# ['neděle', 'sobota', 'pátek', 'čtvrtek', 'středa', 'úterý', 'pondělí']

# %%
dny[-1:3:-1]
# Out:
# ['neděle', 'sobota', 'pátek']

# %%
ceny
# Out:
# [52, 55, 62, 67, 63, 59, 45, 43]

# %%
len(ceny)
# Out:
# 8

# %%
max(ceny)
# Out:
# 67

# %%
min(ceny)
# Out:
# 43

# %%
dny + ceny
# Out:
# ['pondělí',
#  'úterý',
#  'středa',
#  'čtvrtek',
#  'pátek',
#  'sobota',
#  'neděle',
#  52,
#  55,
#  62,
#  67,
#  63,
#  59,
#  45,
#  43]

# %%
44 in ceny
# Out:
# False

# %%
45 in ceny
# Out:
# True

# %%
44 not in ceny
# Out:
# True

# %%
"červenec" not in dny
# Out:
# True

# %%
"úterý" not in dny
# Out:
# False

# %%
"středa" in dny
# Out:
# True

# %%
for dnesni_den in dny:
    print(f"Dneska je {dnesni_den}")
# Out:
# Dneska je pondělí
# Dneska je úterý
# Dneska je středa
# Dneska je čtvrtek
# Dneska je pátek
# Dneska je sobota
# Dneska je neděle
